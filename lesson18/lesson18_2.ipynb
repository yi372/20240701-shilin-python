# %%
import random
import numpy as np
import pandas as pd

with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)

with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df
# Out:
#      國文   英文   數學  地理  歷史
# 趙家豪  94   76   70  85  86
# 孫火清  86   98   64  70  86
# 黃名明  93   90   51  84  78
# 吳孟穎  63   61   82  61  84
# 方雅慧  65   95   71  80  76
# 周怡啟  59   53   87  60  50
# 潘英迪  80   65   90  83  68
# 黃偉剛  57   76   84  99  95
# 杜明延  74   57   80  84  70
# 葉軍仰  71   88   57  82  57
# 賴苑禾  62   86   93  71  96
# 羅幸娥  86   87   60  50  67
# 黃志福  76   66   52  57  76
# 張軒宸  67   66   64  81  57
# 謝哲維  92   58   53  66  64
# 梁柏宇  62   73   51  53  99
# 林希啟  54   54   95  76  94
# 林怡偉  56   68   55  88  89
# 劉昀天  96   79   71  90  74
# 黃名明  73   94   64  91  78
# 謝哲維  73   94  100  62  79
# 陳慧君  59   66   70  53  79
# 胡芳瑜  67   99   70  66  92
# 姜琬婷  77   66   57  79  92
# 王筱婷  62   58   79  84  74
# 陳信念  76   77   59  61  75
# 王明昇  85   62   90  66  69
# 賴又琦  50   87   86  54  83
# 王怡君  76   74   61  72  63
# 張家秀  85   75   79  81  98
# 林俊翔  94   81   70  67  56
# 張韋成  95   71   63  84  77
# 陳得映  97   64   51  86  54
# 楊建安  76   56   70  50  64
# 尚偉倫  73   67   79  76  73
# 李美洋  83   76   76  74  74
# 唐翊修  60   52   54  91  98
# 陳凱翔  94   80   57  91  91
# 王雅琴  71   72   77  80  56
# 林益妏  71   67   56  86  69
# 李慶亮  74   83   94  91  55
# 朱士弘  55   63   68  98  77
# 梁柏宇  50  100   67  58  56
# 游一鈺  57   72   60  75  66
# 楊偉翔  63   75   80  99  71
# 龔姵君  80   82   83  52  72
# 馮芳如  90   62   76  60  56
# 馮耀中  65   78   50  84  56
# 陳倩妮  50   83   74  50  90
# 王明昇  93   86   82  83  63

# %%
from pandas import Series,DataFrame
def fun3(s:Series):
    sum = s.sum()
    mean = s.mean()
    count = s[s<60].count()
    values = s[s<60].index.values
    return Series([sum,mean,count,values],index=['總分','平均','不及格數','不及格科目'])

student_df.apply(fun3,axis=1)
# Out:
#       總分    平均  不及格數         不及格科目
# 趙家豪  411  82.2     0            []
# 孫火清  404  80.8     0            []
# 黃名明  396  79.2     1          [數學]
# 吳孟穎  351  70.2     0            []
# 方雅慧  387  77.4     0            []
# 周怡啟  309  61.8     3  [國文, 英文, 歷史]
# 潘英迪  386  77.2     0            []
# 黃偉剛  411  82.2     1          [國文]
# 杜明延  365  73.0     1          [英文]
# 葉軍仰  355  71.0     2      [數學, 歷史]
# 賴苑禾  408  81.6     0            []
# 羅幸娥  350  70.0     1          [地理]
# 黃志福  327  65.4     2      [數學, 地理]
# 張軒宸  335  67.0     1          [歷史]
# 謝哲維  333  66.6     2      [英文, 數學]
# 梁柏宇  338  67.6     2      [數學, 地理]
# 林希啟  373  74.6     2      [國文, 英文]
# 林怡偉  356  71.2     2      [國文, 數學]
# 劉昀天  410  82.0     0            []
# 黃名明  400  80.0     0            []
# 謝哲維  408  81.6     0            []
# 陳慧君  327  65.4     2      [國文, 地理]
# 胡芳瑜  394  78.8     0            []
# 姜琬婷  371  74.2     1          [數學]
# 王筱婷  357  71.4     1          [英文]
# 陳信念  348  69.6     1          [數學]
# 王明昇  372  74.4     0            []
# 賴又琦  360  72.0     2      [國文, 地理]
# 王怡君  346  69.2     0            []
# 張家秀  418  83.6     0            []
# 林俊翔  368  73.6     1          [歷史]
# 張韋成  390  78.0     0            []
# 陳得映  352  70.4     2      [數學, 歷史]
# 楊建安  316  63.2     2      [英文, 地理]
# 尚偉倫  368  73.6     0            []
# 李美洋  383  76.6     0            []
# 唐翊修  355  71.0     2      [英文, 數學]
# 陳凱翔  413  82.6     1          [數學]
# 王雅琴  356  71.2     1          [歷史]
# 林益妏  349  69.8     1          [數學]
# 李慶亮  397  79.4     1          [歷史]
# 朱士弘  361  72.2     1          [國文]
# 梁柏宇  331  66.2     3  [國文, 地理, 歷史]
# 游一鈺  330  66.0     1          [國文]
# 楊偉翔  388  77.6     0            []
# 龔姵君  369  73.8     1          [地理]
# 馮芳如  344  68.8     1          [歷史]
# 馮耀中  333  66.6     2      [數學, 歷史]
# 陳倩妮  347  69.4     2      [國文, 地理]
# 王明昇  407  81.4     0            []
